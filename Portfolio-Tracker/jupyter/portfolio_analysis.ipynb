# %%
# Portfolio Analysis Dashboard
# Automated portfolio tracking, analysis, and visualization using the portfolio_tracker library.

import sys
sys.path.insert(0, '../src')
import polars as pl

from data_loader import load_transactions, load_positions
from metrics import calculate_portfolio_metrics
from visualization import plot_portfolio_performance, print_portfolio_summary
from rebalancing import calculate_rebalancing

# %%
## 1. Load Data
# Load transactions and current positions from CSV files.

transactions = load_transactions()
positions = load_positions()

print(f"Loaded {transactions.height} transactions")
print(f"Current positions: {positions.height} assets")
# Out:
# Loaded 148 transactions
# Current positions: 3 assets

# %%
## 2. Calculate Portfolio Metrics
# Calculate daily portfolio metrics including returns, P&L, and holdings values.

portfolio_history = calculate_portfolio_metrics(transactions)
print(f"Portfolio history: {portfolio_history.height} days")

## 3. Visualize Performance
# Generate comprehensive performance charts showing portfolio value, P&L, and asset allocation over time.

plot_portfolio_performance(portfolio_history, transactions)
# Out:
# Portfolio history: 487 days

# %%
## 4. Portfolio Summary
# Detailed breakdown of portfolio metrics, allocation, returns, and costs.

print_portfolio_summary(transactions, positions, portfolio_history)
# Out:
# ========================================================================================================================
# INVESTMENT TIMELINE
# ========================================================================================================================
# Start Date:                              2024-08-27
# End Date:                                2025-12-26
# Days Invested:                           486 days (1.33 years)
# First Deposit:                           2024-08-27
# Number of Deposits:                      6
#
# ========================================================================================================================
# ASSET ALLOCATION & PERFORMANCE
# ========================================================================================================================
#
# Symbol   Shares     Avg$       Curr$      Cost Basis    Market Val    Port%     Asset%    Unrealized    Divs       Ret%
# ------------------------------------------------------------------------------------------------------------------------
# VTI      253.00     $294.03    $326.83    $74,389.15    $82,687.99    74.49%    74.49%    $8,298.84     $454.92    11.77%
# VXUS     296.00     $63.98     $73.28     $18,936.69    $21,690.88    19.54%    19.54%    $2,754.19     $396.37    16.64%
# SPY      10.00      $550.95    $662.23    $5,509.50     $6,622.30     5.97%     5.97%     $1,112.80     $51.45     21.13%
# Cash     -          -          -          -             $49.79        0.04    % -         -             -          -
# ------------------------------------------------------------------------------------------------------------------------
# TOTAL                                     $98,835.35    $115,323.79   100.00  % 100.00  % $12,165.82    $902.74    13.22  %
#
# Note: 'Ret%' = (Unrealized P&L + Dividends) / Cost Basis × 100
#       Returns on current holdings only, excluding realized gains from closed positions.
#
# ========================================================================================================================
# PORTFOLIO CAPITAL STRUCTURE
# ========================================================================================================================
# JPY Deposits Total:                      ¥  14,120,000
#   Value if converted today (¥151.82): $   93,004.87
#   Actual USD received:                   $   95,629.20
#   FX Timing Gain:                        $    2,624.33  = (Better conversion timing)
# ------------------------------------------------------------------------------------------------------------------------
# Contributed Capital (C):                 $   95,629.20  = Actual USD from deposits/conversions
# Invested Capital (I):                    $   98,835.35  = Σ(Cost Basis inc. buy commissions)
# Cash (K):                                $       49.79  = C - I + R_cap + D_gross - T_div - T_fees
# Holdings Market Value (H):               $  115,274.00  = Σ(Shares × Current Price)
# ------------------------------------------------------------------------------------------------------------------------
# Total Equity (E):                        $  115,323.79  = K + H
# Portfolio P&L:                           $   19,694.59  = E - C
#
# ========================================================================================================================
# REALIZED INCOME
# ========================================================================================================================
# Realized Capital Gains (R_cap):          $    2,353.52  = Σ[(Sale Price - Sell Commission) - Cost Basis]
# Gross Dividends (D_gross):               $    1,258.61  = Σ(Dividend Payments)
# ------------------------------------------------------------------------------------------------------------------------
# Total Realized Income (before costs):   $    3,612.13  = R_cap + D_gross
#
# ========================================================================================================================
# UNREALIZED GAINS (Open Positions)
# ========================================================================================================================
# Unrealized P&L (U):                      $   16,438.66  = H - I
#
# ========================================================================================================================
# COSTS & TAXES
# ========================================================================================================================
# Trading Commissions:                     $       10.02  [Already included in Invested Capital & Realized Gains]
# Dividend Withholding Tax (T_div):        $      355.87  = Σ(Tax Withheld on Dividends)
# Account Fees (T_fees):                   $        1.51  = Σ(Other Account Fees)
# ------------------------------------------------------------------------------------------------------------------------
# Costs to subtract (T_div + T_fees):      $      357.38  = T_div + T_fees
#
# ========================================================================================================================
# TOTAL INVESTMENT PERFORMANCE
# ========================================================================================================================
# Unrealized Gains:                        $   16,438.66
# Realized Gains (net of commissions):     $    2,353.52
# Gross Dividends:                         $    1,258.61
# Less: Withholding Tax & Fees:            $      357.38
# ------------------------------------------------------------------------------------------------------------------------
# Net Investment P&L:                      $   19,693.41  = U + R_cap + D_gross - T_div - T_fees
# ------------------------------------------------------------------------------------------------------------------------
# Total Portfolio Return (TWR):                  20.59%  = (E / C - 1) × 100
#                                                        [Total return on all contributed capital]
# Annualized TWR:                                15.11%  = [(1 + TWR)^(1/years) - 1] × 100
#
# ========================================================================================================================
# SUMMARY
# ========================================================================================================================
# Total Capital Contributed:               $   95,629.20  (Actual USD from deposits/FX)
#   Note: Deposited ¥14,120,000, gained $2,624.33 vs. converting today
# Current Portfolio Value:                 $  115,323.79
# Net Investment Gain:                     $   19,693.41  (20.59% return)
#   - Realized (after commissions):        $    3,254.75
#   - Unrealized (Paper Gains):            $   16,438.66
# Total External Costs (taxes + fees):     $      357.38
# Total Commissions (embedded in above):   $       10.02
# Annualized Return:                       15.11% per year over 1.33 years
# Current Allocation:                      100.0% equities, 0.0% cash
# ========================================================================================================================

# %%
# ## 5. Rebalancing Calculator (optional)
# # Calculate optimal trades for rebalancing with new investments. Set your target allocation and investment amount below:

# # Define your target allocation (percentages must sum to 100)
# target_allocation = {
#     'VTI': 72,
#     'SPY': 6,
#     'VXUS': 22
# }

# # Amount to invest in USD
# investment_amount = 24000

# calculate_rebalancing(positions, target_allocation, investment_amount=investment_amount)
